# %%
# reading the retail data set
retail <- read.csv("OnlineRetail.csv")

# %%
str(retail)
# Out:
# 'data.frame':	541909 obs. of  8 variables:
#  $ InvoiceNo  : chr  "536365" "536365" "536365" "536365" ...
#  $ StockCode  : chr  "85123A" "71053" "84406B" "84029G" ...
#  $ Description: chr  "WHITE HANGING HEART T-LIGHT HOLDER" "WHITE METAL LANTERN" "CREAM CUPID HEARTS COAT HANGER" "KNITTED UNION FLAG HOT WATER BOTTLE" ...
#  $ Quantity   : int  6 6 8 6 6 2 6 6 6 32 ...
#  $ InvoiceDate: chr  "12/1/2010 8:26" "12/1/2010 8:26" "12/1/2010 8:26" "12/1/2010 8:26" ...
#  $ UnitPrice  : num  2.55 3.39 2.75 3.39 3.39 7.65 4.25 1.85 1.85 1.69 ...
#  $ CustomerID : int  17850 17850 17850 17850 17850 17850 17850 17850 17850 13047 ...
#  $ Country    : chr  "United Kingdom" "United Kingdom" "United Kingdom" "United Kingdom" ...

# %%
df <- data.frame(retail)

# %% [markdown]
# ## Data Cleaning Plan
#
# - Handle missing Customer IDs:
#   - Replace with `"Unknown"`

# %%
any(is.na(df$CustomerID)) # I am checking this because I know there is null, I loaded this csv into local database and when selecting "CustomerID" as a PK it throwed error
df$CustomerID[is.na(df$CustomerID)] <- "Unknown"
any(is.na(df$CustomerID)) # any is used to determine if at least one element withthin a logical vector evulates to TRUE
# Out:
# [1] TRUE
# [1] FALSE

# %%
any(is.na(df)) # We have no missing values in our data frame
# Out:
# [1] FALSE

# %% [markdown]
# ## Abbreviation
#     . We count manually replace every country but it will take time, So I looked up for library.
#     . Found a library called "countrycode"
#     . In our data like  RSA Republic of South Africa are there let's clearn that up, so that library does not throw warning
#     . Here few data are of Islands, let's group that to different category, European Community, Channel Islands and Unspecified to other categories
#     . On one side we have filtered based on known name of country "specified_country" and in other where there is islands and another stuff we added them into seprate data frame "specified_country"
#     . Here we have a bit of a challage, we need to dig deepr in this country, some of them is labeled as USA, some of them are in long form, some of them are in islands.

# %%
library(countrycode)
library(dplyr) 
print("Raw country: ")
print(sort(unique(df$Country)))
# for filter, %in% check element of vector a are present in vector b, it reutns a boolean vector

# how do we know that, well from error using countrycode
# Out:
# [1] "Raw country: "
#  [1] "Australia"            "Austria"              "Bahrain"
#  [4] "Belgium"              "Brazil"               "Canada"
#  [7] "Channel Islands"      "Cyprus"               "Czech Republic"
# [10] "Denmark"              "EIRE"                 "European Community"
# [13] "Finland"              "France"               "Germany"
# [16] "Greece"               "Hong Kong"            "Iceland"
# [19] "Israel"               "Italy"                "Japan"
# [22] "Lebanon"              "Lithuania"            "Malta"
"Channel Islands"    "Channel Islands"    "Channel Islands"
# [538] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [541] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [544] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [547] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [550] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [553] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [556] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [559] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [562] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [565] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [568] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [571] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [574] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [577] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [580] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [583] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [586] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [589] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [592] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [595] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [598] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [601] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [604] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [607] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [610] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [613] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [616] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [619] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [622] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [625] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [628] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [631] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [634] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [637] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [640] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [643] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [646] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [649] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [652] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [655] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [658] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [661] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [664] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [667] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [670] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [673] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [676] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [679] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [682] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [685] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [688] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [691] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [694] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [697] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [700] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [703] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [706] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [709] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [712] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [715] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [718] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [721] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [724] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [727] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [730] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [733] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [736] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [739] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [742] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [745] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [748] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [751] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [754] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [757] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [760] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [763] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [766] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [769] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [772] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [775] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [778] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [781] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [784] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [787] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [790] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [793] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [796] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [799] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [802] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [805] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [808] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [811] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [814] "Channel Islands"    "Channel Islands"    "Channel Islands"
# [817] "Channel Islands"    "Channel Islands"    "Channel Islands"

# %% [markdown]
# ## Let's check for the quantity column
#     . Here we have negative value, physically item sold cannot be negative, so we are taking the absolute value
#     . I looked up for the entry to be exact zero but found none.

# %%
df$Quantity <- abs(df$Quantity) # assuming it a type and conversting to a absolute value 
paste("Quantity with exact zero: ",  sum(df[df$Quantity == 0]), " Quantity with non negative: ", sum(df$Quantity)) # we expect larger number than the dim of df, cause more than one items can be sold
# Out:
# [1] "Quantity with exact zero:  0  Quantity with non negative:  6145512"

# %% [markdown]
# ## Checking for StockCode

# %%
any(is.na(df$StockCode)) # We don't have any nulls in stock code.
any(df$StockCode <= 0)
# Out:
# [1] FALSE
# [1] FALSE

# %% [markdown]
# ## Unit price error check
#     . 2515 items have UnitPrice of zero.
#     . We can find similar product and add the price.
#     . If not then we need to drop the rows because its less significant compared to the size of data.
#     . Here two of the `UnitPrice` came to be negative, `Description` was `Adjust bad dept` so we are dropping that as well.

# %%
any(df[df$UnitPrice < 0])
df <- df[df$UnitPrice > 0, ]
dim(df)
# Out:
# Error in `[.data.frame`(df, df$UnitPrice < 0): undefined columns selected
# Traceback:
#
# 1. `[.data.frame`(df, df$UnitPrice < 0)
# 2. stop("undefined columns selected")
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "undefined columns selected", base::quote(`[.data.frame`(df,
#  .     df$UnitPrice < 0)))

# %% [markdown]
# ## Product Description

# %%
check <- df[df$Description == "", ]
any(is.na(df$Description))
# I don't think we have an missing value over there

# %% [markdown]
# ## Working with date
#     . From raw data, dates are given to us as a character, so we are converting it to date object.

# %%
df$InvoiceDate <- as.Date(df$InvoiceDate, format = "%m/%d/%Y") # %m represents month in decimal, %m represents month in decimal and %y represents the year 
str(df) # if we look at the str we should see the Date object,

# %% [markdown]
# ## Exploratory Data Analysis

# %%
summary(df)
unique(df$Country)
